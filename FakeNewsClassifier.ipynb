# %% [markdown]
# <a href="https://colab.research.google.com/github/percoguru/FakeNewsClassifier/blob/master/FakeNewsClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
fake_news = pd.read_csv("fake.csv")
real_news = pd.read_csv("real_news.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-4a979136a4f8> in <module>()
#       1 fake_news = pd.read_csv("fake.csv")
# ----> 2 real_news = pd.read_csv("real_news.csv")
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: EOF inside string starting at row 11216

# %%
#Here are the size of our datasets:
print(fake_news.shape)
print(real_news.shape)
# Out:
# (12999, 20)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-03f8d2378ef4> in <module>()
#       1 print(fake_news.shape)
# ----> 2 print(real_news.shape)
#
# NameError: name 'real_news' is not defined

# %%
# Let's see what columns we have
print(list(fake_news.columns))
print(list(real_news.columns))
# Out:
# ['uuid', 'ord_in_thread', 'author', 'published', 'title', 'text', 'language', 'crawled', 'site_url', 'country', 'domain_rank', 'thread_title', 'spam_score', 'main_img_url', 'replies_count', 'participants_count', 'likes', 'comments', 'shares', 'type']
# ['Unnamed: 0', 'Unnamed: 0.1', 'id', 'title', 'publication', 'author', 'date', 'year', 'month', 'url', 'content']

# %%
# now let's obtain similar features for both datasets before we combine them
# Let's add our label to the dataset "real" for real news and "fake" for fake news

real_news2 = real_news[['title', 'content', 'author', 'publication']]
real_news2['label'] = 'real'
real_news2.head(15)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                 title  ... label
# 0   House Republicans Fret About Winning Their Hea...  ...  real
# 1   First, a Mixtape. Then a Romance. - The New Yo...  ...  real
# 2   Calling on Angels While Enduring the Trials of...  ...  real
# 3   U.S. Plans to Step Up Military Campaign Agains...  ...  real
# 4   272 Slaves Were Sold to Save Georgetown. What ...  ...  real
# 5   Among Travelers and Commuters, the Homeless St...  ...  real
# 6   Bus Bombing in Jerusalem Wounds 21 - The New Y...  ...  real
# 7   Syria Cease-Fire Crumbles as Bombings Kill Doz...  ...  real
# 8           Iceland’s Water Cure - The New York Times  ...  real
# 9   Get to Know the Historical Figures on the $5, ...  ...  real
# 10  Ramsay Bolton of ‘Game of Thrones’ Is the Most...  ...  real
# 11  Fiat Chrysler Announces Recall of 1.1 Million ...  ...  real
# 12  Prince Is Mourned by Fashion World, Which Coun...  ...  real
# 13  Prince, an Artist Who Defied Genre, Is Dead at...  ...  real
# 14  Melissa Gilbert Never Saw Congress in Her Futu...  ...  real
#
# [15 rows x 4 columns]

# %%
fake_news2 = fake_news[['title', 'text', 'author', 'site_url']]
fake_news2['label'] = 'fake'
fake_news2.head(15)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                 title  ... label
# 0   Muslims BUSTED: They Stole Millions In Gov’t B...  ...  fake
# 1   Re: Why Did Attorney General Loretta Lynch Ple...  ...  fake
# 2   BREAKING: Weiner Cooperating With FBI On Hilla...  ...  fake
# 3   PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...  ...  fake
# 4   FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...  ...  fake
# 5   Hillary Goes Absolutely Berserk On Protester A...  ...  fake
# 6   BREAKING! NYPD Ready To Make Arrests In Weiner...  ...  fake
# 7   WOW! WHISTLEBLOWER TELLS CHILLING STORY Of Mas...  ...  fake
# 8   BREAKING: CLINTON CLEARED...Was This A Coordin...  ...  fake
# 9   EVIL HILLARY SUPPORTERS Yell "F*ck Trump"…Burn...  ...  fake
# 10  YIKES! HILLARY GOES OFF THE RAILS…Pulls A Howa...  ...  fake
# 11  SAY GOODBYE! These 23 Hollywood Celebs Threate...  ...  fake
# 12  NOT KIDDING: Colleges Give Students “Safe Spac...  ...  fake
# 13  BOOM! MATH SHOWS Trump Would Have Beaten Obama...  ...  fake
# 14  BOOM! This Is How President Reagan Handled Pro...  ...  fake
#
# [15 rows x 4 columns]

# %%
# let's obtain all the unique site_urls
site_urls = fake_news2['site_url']

# let's remove the domain extensions
site_urls2 = [x.split('.',1)[0] for x in site_urls]

# now let's replace the old site_url column
fake_news2['site_url'] = site_urls2
fake_news2.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                                title  ... label
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...  ...  fake
# 1  Re: Why Did Attorney General Loretta Lynch Ple...  ...  fake
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...  ...  fake
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...  ...  fake
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...  ...  fake
#
# [5 rows x 4 columns]

# %%
# let's rename the features in our datasets to be the same
newlabels = ['title', 'content', 'publication', 'label']
real_news2.columns = newlabels
fake_news2.columns = newlabels

# let's concatenate the dataframes
frames = [fake_news2, real_news2]
news_dataset = pd.concat(frames)
news_dataset
# Out:
#                                                    title  ... label
# 0      Muslims BUSTED: They Stole Millions In Gov’t B...  ...  fake
# 1      Re: Why Did Attorney General Loretta Lynch Ple...  ...  fake
# 2      BREAKING: Weiner Cooperating With FBI On Hilla...  ...  fake
# 3      PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...  ...  fake
# 4      FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...  ...  fake
# 5      Hillary Goes Absolutely Berserk On Protester A...  ...  fake
# 6      BREAKING! NYPD Ready To Make Arrests In Weiner...  ...  fake
# 7      WOW! WHISTLEBLOWER TELLS CHILLING STORY Of Mas...  ...  fake
# 8      BREAKING: CLINTON CLEARED...Was This A Coordin...  ...  fake
# 9      EVIL HILLARY SUPPORTERS Yell "F*ck Trump"…Burn...  ...  fake
# 10     YIKES! HILLARY GOES OFF THE RAILS…Pulls A Howa...  ...  fake
# 11     SAY GOODBYE! These 23 Hollywood Celebs Threate...  ...  fake
# 12     NOT KIDDING: Colleges Give Students “Safe Spac...  ...  fake
# 13     BOOM! MATH SHOWS Trump Would Have Beaten Obama...  ...  fake
# 14     BOOM! This Is How President Reagan Handled Pro...  ...  fake
# 15     TRUMP SUPPORTER GOT NUTS On MSNBC Reporter Cov...  ...  fake
# 16     TOMI LAHREN Has Special Message For Celebritie...  ...  fake
# 17     #BoycottComedian…ROBERT DENIRO Wanted “To Punc...  ...  fake
# 18     HE’S NEVER SOLD AN ORIGINAL PAINTING UNTIL NOW...  ...  fake
# 19     SORRY LIBERALS…You Can Stop With The Petitions...  ...  fake
# 20     MARK CUBAN: "In The Event Donald Wins, I Have ...  ...  fake
# 21     TRUMP SUPPORTER Whose Brutal Beating By Black ...  ...  fake
# 22     WOW! WHITE Liberals Suggest Blacks Are Too Stu...  ...  fake
# 23     LOL! BRITISH WIFE Of LIB ACTOR Who Said: “Ther...  ...  fake
# 24     EPIC! TUCKER CARLSON Demolishes NYC Councilman...  ...  fake
# 25     FUNNY! SNL’S SOLUTION To Democrat Election Den...  ...  fake
# 26     DONALD TRUMP Calls Meeting With Press…Dresses ...  ...  fake
# 27     OOPS! CRYBABY HAMILTON STARS Who Lectured Penc...  ...  fake
# 28     WHITE TRUMP-BASHING LIB Reprimanded On LIVE CN...  ...  fake
# 29         BOOM! Kellyanne Conway Shuts Down CNN’s Cuomo  ...  fake
# ...                                                  ...  ...   ...
# 15682  Which senators will stand up to Trump, and whi...  ...  real
# 15683  Cease-fire to begin across Syria starting at m...  ...  real
# 15684  Democrats’ new leader suggests John Kerry just...  ...  real
# 15685  An obscure E.U. regulation may have saved live...  ...  real
# 15686  Rare coast-to-coast cold snap to engulf Lower ...  ...  real
# 15687  The world today looks ominously like it did be...  ...  real
# 15688  The Asian American ‘advantage’ that is actuall...  ...  real
# 15689  A CIA calendar the CIA gift shop refuses to se...  ...  real
# 15690  A woman ordered canaries to brighten her home....  ...  real
# 15691  Putin says he won’t deport U.S. diplomats as h...  ...  real
# 15692  Trump praises Putin’s response to sanctions, c...  ...  real
# 15693  Russia slams Obama administration and CNN for ...  ...  real
# 15694  N.C.’s outgoing GOP governor appears to make o...  ...  real
# 15695  How Indiana’s school voucher program soared, a...  ...  real
# 15696  She was on course for stardom. Then she entrus...  ...  real
# 15697                  2016: One year in the Upside Down  ...  real
# 15698  On Russia, Trump is incapable of looking past ...  ...  real
# 15699  Kerry manages to alienate our closest friends ...  ...  real
# 15700  Hamilton helped elect his rival to keep an ‘un...  ...  real
# 15701            2017 is not looking so good for Germany  ...  real
# 15702                  What U.S. Muslims fear from Trump  ...  real
# 15703         Trump refuses to face reality about Russia  ...  real
# 15704  British leader Theresa May breaks with John Ke...  ...  real
# 15705  China’s vow to shut down its ivory trade by th...  ...  real
# 15706  A Mormon Tabernacle Choir member is resigning ...  ...  real
# 15707  An eavesdropping Uber driver saved his 16-year...  ...  real
# 15708  Plane carrying six people returning from a Cav...  ...  real
# 15709  After helping a fraction of homeowners expecte...  ...  real
# 15710  Yes, this is real: Michigan just banned bannin...  ...  real
# 15711  What happened in Washington state after voters...  ...  real
#
# [28711 rows x 4 columns]

# %%
print(news_datset[0,4])

# %%
label_encoder = LabelEncoder()
news_dataset[:, 4] = label_encoder.fit_transform(news_dataset[:, 4])
